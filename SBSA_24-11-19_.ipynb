# %%
import numpy as np
import pandas as pd

# %%
x=[50,53,54,25,16,18,34,40,90,40,22]
#bins=[20,40,80,90,100]
bins=[100,80,60,40,20]

# %%
y=pd.cut(x,bins)
y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9066134ac71f> in <module>
# ----> 1 y=pd.cut(x,bins)
#       2 y
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     233         bins = _convert_bin_to_numeric_type(bins, dtype)
#     234         if (np.diff(bins) < 0).any():
# --> 235             raise ValueError('bins must increase monotonically.')
#     236
#     237     fac, bins = _bins_to_cuts(x, bins, right=right, labels=labels,
#
# ValueError: bins must increase monotonically.

# %%
df=pd.read_excel("dummy.xlsx")

# %%
df.head(10)
# Out:
#         Date    Name    Age Course  Graduation Year  Education Gap in years
# 0 2019-01-01    Inam  202.0     Ai           2009.0                     5.0
# 1 2019-01-02  Fayyaz   24.0     ai           2016.0                     0.0
# 2 2019-02-03    Asad   22.0     AI           2017.0                     0.0
# 3 2019-03-03   Komal    NaN   cnCf              NaN                     0.0
# 4 2019-03-04    Aqsa    NaN     ai           2019.0                     0.0
# 5 2019-01-02  Fayyaz   24.0    bsc              NaN                     0.0
# 6 2019-02-03    Asad   22.0     be              NaN                     0.0
# 7 2019-02-04   Aamir   28.0    Cnf              NaN                     NaN

# %%
courses = pd.get_dummies(df['Course'])
courses
# Out:
#    AI  Ai  CNCF
# 0   0   1     0
# 1   1   0     0
# 2   1   0     0
# 3   0   0     0
# 4   1   0     0
# 5   1   0     0
# 6   1   0     0
# 7   0   0     1

# %%
df.isnull()
# Out:
#     Date   Name    Age  Course  Graduation Year  Education Gap in years  \
# 0  False  False  False   False            False                   False
# 1  False  False  False   False            False                   False
# 2  False  False  False   False            False                   False
# 3  False  False   True    True             True                   False
# 4  False  False   True   False            False                   False
# 5  False  False  False   False             True                   False
# 6  False  False  False   False             True                   False
#
#    Unnamed: 6  Unnamed: 7
# 0        True        True
# 1        True        True
# 2        True        True
# 3        True       False
# 4        True       False
# 5        True       False
# 6        True       False

# %%
movies = [{
    'gener': 'Action',
    'ReleaseYear': 2019,
    'Name': '21 Bridges',
    
},
{
    'gener': 'Animie',
    'ReleaseYear': 2019,
    'Name': 'Frozen II',
    
},{
    'gener': 'Action',
    'ReleaseYear': 2020,
    'Name': 'Black Widow'
},{
    'gener': 'Action, Darama',
    'ReleaseYear': 2019,
    'Name': 'Joker'
}]

# %%
df = pd.DataFrame(movies)

# %%
df.head()
# Out:
#           Name  ReleaseYear           gener
# 0   21 Bridges         2019          Action
# 1    Frozen II         2019          Animie
# 2  Black Widow         2020          Action
# 3        Joker         2019  Action, Darama

# %%
dummy = pd.get_dummies(df['ReleaseYear'])
dummy
# Out:
#    2019  2020
# 0     1     0
# 1     1     0
# 2     0     1
# 3     1     0

# %%
df2 = df.join(dummy)

# %%
c = '1,2,33,45,555,6'
print(c.split(','))
# Out:
# ['1', '2', '33', '45', '555', '6']

# %%
df2.head()
# Out:
#           Name  ReleaseYear           gener  2019  2020
# 0   21 Bridges         2019          Action     1     0
# 1    Frozen II         2019          Animie     1     0
# 2  Black Widow         2020          Action     0     1
# 3        Joker         2019  Action, Darama     1     0

# %%
df.head()
# Out:
#         Date    Name    Age Course  Graduation Year  Education Gap in years
# 0 2019-01-01    Inam  202.0     Ai           2009.0                     5.0
# 1 2019-01-02  Fayyaz   24.0     ai           2016.0                     0.0
# 2 2019-02-03    Asad   22.0     AI           2017.0                     0.0
# 3 2019-03-03   Komal    NaN   cnCf              NaN                     0.0
# 4 2019-03-04    Aqsa    NaN     ai           2019.0                     0.0

# %%
df["Course"]=df["Course"].str.upper()

# %%
df.head()
# Out:
#         Date    Name    Age Course  Graduation Year  Education Gap in years
# 0 2019-01-01    Inam  202.0     AI           2009.0                     5.0
# 1 2019-01-02  Fayyaz   24.0     AI           2016.0                     0.0
# 2 2019-02-03    Asad   22.0     AI           2017.0                     0.0
# 3 2019-03-03   Komal    NaN   CNCF              NaN                     0.0
# 4 2019-03-04    Aqsa    NaN     AI           2019.0                     0.0
